# %%
import csv
# open lab1copy
# write lab1py

with open("lab1.csv") as f:
    reader = csv.DictReader(f)
    data = [r for r in reader]
    print(type(data))
#     print(data)
    for good in data:
#         print ("\n".join(good))
#         print(type(good))
#         good['Run 1: Time (s)'] = round(number, 3)
        for key, value in good.items():
            print(key, value)
            
            def truncate(f, n):
                s = '%.12f' % f
                i, p, d = s.partition('.')
                return '.'.join([i, (d+'0'*n)[:n]])
            
            tempNum = str(truncate(float(value), 3))
            while tempNum[::-1].find('.') != 3:
                print("hello")
                num+="0"
                print(tempNum)
            
            
            good[key] = tempNum
            print(tempNum)
            print(good[key])
            


    

    
    keys = data[0].keys()
    with open('labpaaaa.csv', 'w') as output_file:
        dict_writer = csv.DictWriter(output_file, keys)
        dict_writer.writeheader()
        dict_writer.writerows(data)
# Out:
# <class 'list'>
# Run 1: Time (s) 0.01654
# 0.016
# 0.016
# Run 1: Gate State 0
# 0.000
# 0.000
# Run 1: Distance (m) 0.015
# 0.015
# 0.015
# Run 1: Velocity (m/s) 0.908
# 0.908
# 0.908
# Run 1: Acceleration (m/s^2) 0.06
# 0.060
# 0.060
# Run 2: Time (s) 0.01756
# 0.017
# 0.017
# Run 2: Gate State 1
# 1.000
# 1.000
# Run 2: Distance (m) 0.015
# 0.015
# 0.015
# Run 2: Velocity (m/s) 0.856
# 0.856
# 0.856
# Run 2: Acceleration (m/s^2) 0.21
# 0.210
# 0.210
# Run 3: Time (s) 0.02876
# 0.028
# 0.028
# Run 3: Gate State 1
# 1.000
# 1.000
# Run 3: Distance (m) 0.015
# 0.015
# 0.015
# Run 3: Velocity (m/s) 0.725
# 0.725
# 0.725
# Run 3: Acceleration (m/s^2) 14.16
# 14.160
# 14.160
# Run 4: Time (s) 0.03353
# 0.033
# 0.033
# Run 4: Gate State 1
# 1.000
# 1.000
# Run 4: Distance (m) 0.015
# 0.015
# 0.015
# Run 4: Velocity (m/s) 0.895
# 0.895
# 0.895
# Run 4: Acceleration (m/s^2) 26.68
# 26.680
# 26.680
# Run 1: Time (s) 0.03306
# 0.033
# 0.033
# Run 1: Gate State 0
# 0.000
# 0.000
# ...

# %%
print(round(0.01654, 3))


n = 0.3
str(n)[:5]
# Out:
# 0.017
# '0.3'

# %%
print(math.floor(22.99))
# Out:
# 22

# %%
num = str(0.22)
print(num[::-1].find('.'))


while num[::-1].find('.') != 3:
    print("hello")
    num+="0"
    print(num)
    
    
# int(math.log10(0.225))+1
# Out:
# 2
# hello
# 0.220

# %%
#Data table with time, position, speed, and acceleration data.



import plotly
