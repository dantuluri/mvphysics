# %%
import csv
import glob
import pandas as pd
import numpy as np







print(glob.glob('dynamicsdata/*.csv'))

for fname in glob.glob('dynamicsdata/*.csv'):
    print(fname)
    with open(fname, 'r') as inp, open(fname[:fname.index('.csv')]+'_done.csv', 'w') as out:
        writer = csv.writer(out)
#         df = pd.DataFrame(fname, columns = ['time', 'force', 'distance', 'velocity', 'acceleration'])
        for row in csv.reader(inp):
            print(row)
            print(type(row))
            row.pop(0)
            del row[1:4]
            print(row)
            if len(row)==2:
                if row[1]:
                    writer.writerow(row)
            

                
# allFiles = glob.glob('dynamicsdata/*.csv')
# frame = pd.DataFrame()
# list_ = []
# for file_ in allFiles:
#     df = pd.read_csv(file_,index_col=None, header=0)
#     list_.append(df)
# frame = pd.concat(list_)



# directory = os.path.join("dynamicsdata")
# for root,dirs,files in os.walk(directory):
#     for file in files:
#        if file.endswith(".csv"):
#            f=open(file, 'r')
#            print (file, f.readline())
#            f.close()
# Out:
# ['dynamicsdata/trial1.csv', 'dynamicsdata/trial44.csv', 'dynamicsdata/trial3.csv', 'dynamicsdata/trial6.csv', 'dynamicsdata/trial41.csv', 'dynamicsdata/trial40.csv', 'dynamicsdata/trial7.csv', 'dynamicsdata/trial5.csv', 'dynamicsdata/trial42.csv', 'dynamicsdata/trial43.csv', 'dynamicsdata/trial4.csv', 'dynamicsdata/trial30.csv', 'dynamicsdata/trial24.csv', 'dynamicsdata/trial18.csv', 'dynamicsdata/trial19.csv', 'dynamicsdata/trial25.csv', 'dynamicsdata/trial31.csv', 'dynamicsdata/trial27.csv', 'dynamicsdata/trial33.csv', 'dynamicsdata/trial32.csv', 'dynamicsdata/trial26.csv', 'dynamicsdata/trial22.csv', 'dynamicsdata/trial36.csv', 'dynamicsdata/trial37.csv', 'dynamicsdata/trial23.csv', 'dynamicsdata/trial35.csv', 'dynamicsdata/trial21.csv', 'dynamicsdata/trial20.csv', 'dynamicsdata/trial34.csv', 'dynamicsdata/trial11.csv', 'dynamicsdata/trial39.csv', 'dynamicsdata/trial38.csv', 'dynamicsdata/trial10.csv', 'dynamicsdata/trial12.csv', 'dynamicsdata/trial13.csv', 'dynamicsdata/trial17.c
# ...

# %% [markdown]
# # hello = 'hola'
# print(hello+'_no')

# %%
x = 'trial_2.csv'
y = 'trial_23.csv'
print(x.index('.csv'))
print(y.index('.csv'))
print(x[:x.index('.csv')]+'_done.csv')
print(y[:y.index('.csv')])
# Out:
# 7
# 8
# trial_2_done.csv
# trial_23

# %%
arr = ['0.18170', '-0.49', '0', '0.250', '2.582', '13.58']
print(arr)

arr.pop(0)
del arr[1:4]

print(arr)

b = ['0.04141', '-0.40', '0', '', '', '']

if not b[3]:
    print('no element!')
# Out:
# ['0.18170', '-0.49', '0', '0.250', '2.582', '13.58']
# ['-0.49', '13.58']
# no element!
